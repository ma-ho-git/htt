# %%
import queries

# %%
print(dir(queries)[0])

# %%
statement = []

for sql in dir(queries):
    if not sql.startswith('__'):
        statement.append(sql)

statement

# %%
[sql for sql in dir(queries) if not sql.startswith('__') ]

# %%
import DBcm

db_details = "CoachDB.sqlite3"

from queries import SQL_SESSIONS

print(SQL_SESSIONS)

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SESSIONS)
    results = db.fetchall()
results

# %%
# !python3 update_tables.py

# %%
from queries import SQL_SWIMMERS_BY_SESSION

print(SQL_SWIMMERS_BY_SESSION)

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SWIMMERS_BY_SESSION,("2024-08-10",))
    results = db.fetchall()
results

# %%
from queries import SQL_SWIMMERS_EVENTS_BY_SESSION

print(SQL_SWIMMERS_EVENTS_BY_SESSION)
# Out:
#
#     select distinct events.distance, events.stroke
#     from swimmers, events, times
#     where times.swimmer_id = swimmers.id and
#     times.event_id = events.id and
#     (swimmers.name = ? and swimmers.age = ?) and
#     date(times.ts) = ?

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SWIMMERS_EVENTS_BY_SESSION, ("Darius",8, "2024-08-10",))
    results = db .fetchall()
results
# Out:
# [('50m', 'Breast'), ('50m', 'Back'), ('50m', 'Free')]

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SWIMMERS_EVENTS_BY_SESSION, ("Owen", 15, "2024-08-10",))
    results = db .fetchall()
results
# Out:
# [('100m', 'Free')]

# %%
SQL_GET_ALL_TIMES = """
    select * from times
"""

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_GET_ALL_TIMES)
    results = db .fetchall()
results

# %%
SQL_GET_ALL_EVENTS = """
    select * from events
"""

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_GET_ALL_EVENTS)
    results = db .fetchall()
results
# Out:
# [(1, '100m', 'Free'),
#  (2, '100m', 'Back'),
#  (3, '50m', 'Free'),
#  (4, '200m', 'Breast'),
#  (5, '50m', 'Fly'),
#  (6, '50m', 'Back'),
#  (7, '200m', 'Back'),
#  (8, '100m', 'Breast'),
#  (9, '200m', 'IM'),
#  (10, '200m', 'Free'),
#  (11, '100m', 'Fly'),
#  (12, '50m', 'Breast'),
#  (13, '400m', 'Free')]

# %%
SQL_GET_ALL_SWIMMERS = """
    select * from swimmers
"""

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_GET_ALL_SWIMMERS)
    results = db .fetchall()
results
# Out:
# [(182, 'Alison', 14),
#  (183, 'Ruth', 13),
#  (184, 'Tasmin', 15),
#  (185, 'Blake', 15),
#  (186, 'Maria', 9),
#  (187, 'Katie', 9),
#  (188, 'Darius', 13),
#  (189, 'Erika', 15),
#  (190, 'Lizzie', 14),
#  (191, 'Mike', 15),
#  (192, 'Emma', 13),
#  (193, 'Carl', 15),
#  (194, 'Ali', 12),
#  (195, 'Calvin', 9),
#  (196, 'Dave', 17),
#  (197, 'Chris', 17),
#  (198, 'Hannah', 13),
#  (199, 'Abi', 10),
#  (200, 'Owen', 15),
#  (201, 'Bill', 18),
#  (202, 'Elba', 14),
#  (203, 'Aurora', 13),
#  (204, 'Darius', 8)]

# %%
from queries import SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION

print(SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION)
# Out:
#     select times.time
#     from swimmers, events, times
#     where (swimmers.name = ? and swimmers.age = ?) and
#     (events.distance = ? and events.stroke = ?) and
#     swimmers.id = times.swimmer_id and
#     events.id = times.event_id and
#     date(times.ts) = ?

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION,("Darius",13,"100m","Fly","2024-08-10",))
    results = db.fetchall()
results
# Out:
# [('1:27.95',),
#  ('1:21.07',),
#  ('1:30.96',),
#  ('1:23.22',),
#  ('1:27.95',),
#  ('1:28.30',),
#  ('1:27.95',),
#  ('1:21.07',),
#  ('1:30.96',),
#  ('1:23.22',),
#  ('1:27.95',),
#  ('1:28.30',),
#  ('1:27.95',),
#  ('1:21.07',),
#  ('1:30.96',),
#  ('1:23.22',),
#  ('1:27.95',),
#  ('1:28.30',),
#  ('1:27.95',),
#  ('1:21.07',),
#  ('1:30.96',),
#  ('1:23.22',),
#  ('1:27.95',),
#  ('1:28.30',),
#  ('1:27.95',),
#  ('1:21.07',),
#  ('1:30.96',),
#  ('1:23.22',),
#  ('1:27.95',),
#  ('1:28.30',),
#  ('1:23.22',),
#  ('1:21.07',),
#  ('1:27.95',),
#  ('1:27.95',),
#  ('1:28.30',),
#  ('1:30.96',)]
