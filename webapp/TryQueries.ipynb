# %%
import queries

# %%
print(dir(queries)[0])
# Out:
# SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION

# %%
statement = []

for sql in dir(queries):
    if not sql.startswith('__'):
        statement.append(sql)

statement
# Out:
# ['SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION',
#  'SQL_SESSIONS',
#  'SQL_SWIMMERS_BY_SESSION',
#  'SQL_SWIMMERS_EVENTS_BY_SESSION']

# %%
[sql for sql in dir(queries) if not sql.startswith('__') ]
# Out:
# ['SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION',
#  'SQL_SESSIONS',
#  'SQL_SWIMMERS_BY_SESSION',
#  'SQL_SWIMMERS_EVENTS_BY_SESSION']

# %%
import DBcm

db_details = "CoachDB.sqlite3"

from queries import SQL_SESSIONS

print(SQL_SESSIONS)
# Out:
#     select distinct ts from times

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SESSIONS)
    results = db.fetchall()
results
# Out:
# [('2024-08-09 09:59:20',), ('2024-08-09 17:10:34',)]

# %%
# !python3 update_tables.py

# %%
from queries import SQL_SWIMMERS_BY_SESSION

print(SQL_SWIMMERS_BY_SESSION)
# Out:
#     select distinct swimmers.name, swimmers.age
#     from times, swimmers
#     where date(times.ts) = ? and
#     times.swimmer_id = swimmers.id
#     order by name

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SWIMMERS_BY_SESSION,("2024-08-09"),)
    results = db.fetchall()
results
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 2
#       1 with DBcm.UseDatabase(db_details) as db:
# ----> 2     db.execute(SQL_SWIMMERS_BY_SESSION,("2024-08-09"),)
#       3     results = db.fetchall()
#
# ProgrammingError: Incorrect number of bindings supplied. The current statement uses 1, and there are 10 supplied.
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 with DBcm.UseDatabase(db_details) as db:
#       2     db.execute(SQL_SWIMMERS_BY_SESSION,("2024-08-09"),)
#       3     results = db.fetchall()
#
# File ~/Documents/code/python/learning/htt/webapp/.venv/lib/python3.12/site-packages/DBcm.py:118, in UseDatabase.__exit__(self, exc_type, exc_value, exc_traceback)
#     116     raise SQLError(exc_value)
#     117 elif exc_type:
# --> 118     raise exc_type(exc_value)
#
# ProgrammingError: Incorrect number of bindings supplied. The current statement uses 1, and there are 10 supplied.
