# %%
import queries

# %%
print(dir(queries)[0])

# %%
statement = []

for sql in dir(queries):
    if not sql.startswith('__'):
        statement.append(sql)

statement

# %%
[sql for sql in dir(queries) if not sql.startswith('__') ]

# %%
import DBcm

db_details = "CoachDB.sqlite3"

from queries import SQL_SESSIONS

print(SQL_SESSIONS)

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SESSIONS)
    results = db.fetchall()
results

# %%
# !python3 update_tables.py

# %%
from queries import SQL_SWIMMERS_BY_SESSION

print(SQL_SWIMMERS_BY_SESSION)

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SWIMMERS_BY_SESSION,("2024-08-10",))
    results = db.fetchall()
results

# %%
from queries import SQL_SWIMMERS_EVENTS_BY_SESSION

print(SQL_SWIMMERS_EVENTS_BY_SESSION)

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SWIMMERS_EVENTS_BY_SESSION, ("Darius",10, "2024-08-10",))
    results = db .fetchall()
results

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_SWIMMERS_EVENTS_BY_SESSION, ("Owen", 10, "2024-08-10",))
    results = db .fetchall()
results

# %%
SQL_GET_ALL_TIMES = """
    select * from times
"""

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_GET_ALL_TIMES)
    results = db .fetchall()
results

# %%
SQL_GET_ALL_EVENTS = """
    select * from events
"""

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_GET_ALL_EVENTS)
    results = db .fetchall()
results
# Out:
# [(1, '100m', 'Free'),
#  (2, '100m', 'Back'),
#  (3, '50m', 'Free'),
#  (4, '200m', 'Breast'),
#  (5, '50m', 'Fly'),
#  (6, '50m', 'Back'),
#  (7, '200m', 'Back'),
#  (8, '100m', 'Breast'),
#  (9, '200m', 'IM'),
#  (10, '200m', 'Free'),
#  (11, '100m', 'Fly'),
#  (12, '50m', 'Breast'),
#  (13, '400m', 'Free')]
